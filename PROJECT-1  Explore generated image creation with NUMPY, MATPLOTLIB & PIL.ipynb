# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from PIL import Image

# %%
Bird_image=Image.open(r'C:\Users\Shriniwas\Downloads\Kingfisher_bird.jpg')
Bird_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1125x750>

# %%
type(Bird_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(Bird_image)
pic_arr
# Out:
# array([[[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        [[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        [[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        ...,
#
#        [[181, 154,  51],
#         [181, 154,  51],
#         [181, 154,  51],
#         ...,
#         [203, 180,  87],
#         [203, 180,  87],
#         [203, 180,  87]],
#
#        [[181, 154,  51],
#         [181, 154,  51],
#         [181, 154,  51],
#         ...,
#         [203, 180,  87],
#         [203, 180,  87],
#         [203, 180,  87]],
#
#        [[181, 154,  49],
#         [181, 154,  49],
#         [181, 154,  49],
# ...

# %%
plt.imshow(pic_arr)

# %%
pic_arr.shape
# Out:
# (750, 1125, 3)

# %%
bird_red=pic_arr.copy()

# %%
bird_red
# Out:
# array([[[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        [[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        [[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        ...,
#
#        [[181, 154,  51],
#         [181, 154,  51],
#         [181, 154,  51],
#         ...,
#         [203, 180,  87],
#         [203, 180,  87],
#         [203, 180,  87]],
#
#        [[181, 154,  51],
#         [181, 154,  51],
#         [181, 154,  51],
#         ...,
#         [203, 180,  87],
#         [203, 180,  87],
#         [203, 180,  87]],
#
#        [[181, 154,  49],
#         [181, 154,  49],
#         [181, 154,  49],
# ...

# %%
pic_arr==bird_red
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
plt.imshow(bird_red)

# %%
plt.imshow(bird_red[:,:,0],cmap='Greys')

# %%
plt.imshow(bird_red[:,:,0],cmap='grey')

# %%
plt.imshow(bird_red[:,:,0],cmap='YlGn')

# %%
bird_red[:,:,0]
# Out:
# array([[250, 250, 250, ..., 249, 249, 249],
#        [250, 250, 250, ..., 249, 249, 249],
#        [250, 250, 250, ..., 249, 249, 249],
#        ...,
#        [181, 181, 181, ..., 203, 203, 203],
#        [181, 181, 181, ..., 203, 203, 203],
#        [181, 181, 181, ..., 203, 203, 203]], dtype=uint8)

# %%
bird_red[:,:,1]
# Out:
# array([[191, 191, 191, ..., 198, 198, 198],
#        [191, 191, 191, ..., 198, 198, 198],
#        [191, 191, 191, ..., 198, 198, 198],
#        ...,
#        [154, 154, 154, ..., 180, 180, 180],
#        [154, 154, 154, ..., 180, 180, 180],
#        [154, 154, 154, ..., 180, 180, 180]], dtype=uint8)

# %%
bird_red[:,:,2]
# Out:
# array([[131, 131, 131, ..., 141, 141, 141],
#        [131, 131, 131, ..., 141, 141, 141],
#        [131, 131, 131, ..., 141, 141, 141],
#        ...,
#        [ 51,  51,  51, ...,  87,  87,  87],
#        [ 51,  51,  51, ...,  87,  87,  87],
#        [ 49,  49,  49, ...,  87,  87,  87]], dtype=uint8)

# %%
plt.imshow(bird_red)

# %%
Bird_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1125x750>

# %%
pic_arr
# Out:
# array([[[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        [[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        [[250, 191, 131],
#         [250, 191, 131],
#         [250, 191, 131],
#         ...,
#         [249, 198, 141],
#         [249, 198, 141],
#         [249, 198, 141]],
#
#        ...,
#
#        [[181, 154,  51],
#         [181, 154,  51],
#         [181, 154,  51],
#         ...,
#         [203, 180,  87],
#         [203, 180,  87],
#         [203, 180,  87]],
#
#        [[181, 154,  51],
#         [181, 154,  51],
#         [181, 154,  51],
#         ...,
#         [203, 180,  87],
#         [203, 180,  87],
#         [203, 180,  87]],
#
#        [[181, 154,  49],
#         [181, 154,  49],
#         [181, 154,  49],
# ...

# %%
arr1= np.asarray(Bird_image)

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape
# Out:
# (750, 1125, 3)

# %%
plt.imshow(Bird_image)

# %%
Bird_image1= arr1.copy()

# %%
Bird_image1[:,:,0]=0

# %%
plt.imshow(Bird_image1)

# %%
Bird_image1[:,:,1]=0
plt.imshow(Bird_image1)

# %%
Bird_image1[:,:,2]=0
plt.imshow(Bird_image1)

# %%
print(f"\nCompleted !!....\nImage to Array(CV)")
# Out:
# Completed !!....
# Image to Array(CV)
