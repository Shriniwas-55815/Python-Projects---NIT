# %%
# MOVIE RATING ANALYTICS (ADVANCED VISULIZATION)

import pandas as pd
import os

# %%
os.getcwd() # if you want to change the working directory
# Out:
# 'c:\\Users\\Shriniwas\\Desktop\\Program File'

# %%
os.path.abspath('Movie-Rating.csv') # if you want path address by File Name
# Out:
# 'c:\\Users\\Shriniwas\\Desktop\\Program File\\Movie-Rating.csv'

# %%
os.chdir("c:\\Users\\Shriniwas\\Desktop")

# %%
newd = os.getcwd()
newd
# Out:
# 'c:\\Users\\Shriniwas\\Desktop'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Shriniwas\\Desktop'

# %%
os.chdir("c:\\Users\\Shriniwas\\Desktop\\Program File")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Shriniwas\\Desktop\\Program File'

# %%
movies= pd.read_csv(r"C:\Users\Shriniwas\Desktop\Data Analyst Course\Python Basic\11. 30_Nov_2024\29th, 30th - iris dataset\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
len(movies)
# Out:
# 559

# %%
len(movies.columns)
# Out:
# 6

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies['Film'] = movies['Film'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Year = movies.Year.astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## JOINTPLOT

# %%
vish1 = sns.jointplot(data=movies, x = 'CriticRating', y ='AudienceRating')

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
vish2 = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', color= 'red', kind='reg')

# %%
vish3 = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', color= 'green', kind = 'hex')

# %%
vish4 = sns.jointplot(data = movies, x = 'CriticRating', y= 'AudienceRating', color= 'blue', kind='kde')

# %% [markdown]
# # LMPLOT

# %%
vish5 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
vish6 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',fit_reg=False, hue= 'Genre')

# %%
vish7 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', 
                   fit_reg=False, hue= 'Genre')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
vish8 = sns.lmplot(data = movies,  y ='Year', x = 'BudgetMillions')
vish9 = sns.lmplot(data = movies,  y ='Year', x = 'BudgetMillions', fit_reg=False, hue ='Genre')

# %% [markdown]
# # Histogram  - Distplot, Displot, Histplot

# %%
movies.head(2)
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008

# %%
vish10= sns.distplot(movies.CriticRating )
plt.title('*********Critic Rating*********')
plt.show()

# %%
vish11 = sns.distplot(movies.AudienceRating)

# %%
vish12 = sns.displot(movies.AudienceRating)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
h1 = sns.histplot(movies.Genre, kde= True)

# %%
h2 = sns.histplot(movies.Genre, bins=2, kde= False)
plt.title('Genre Distribution', fontsize=16)
plt.show()

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies.Genre)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Adventure'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Horror'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Romance'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=20)
plt.show()

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
        movies[movies.Genre=='Adventure'].BudgetMillions,\
        movies[movies.Genre=='Thriller'].BudgetMillions,\
        movies[movies.Genre=='Drama'].BudgetMillions], \
         bins=20, stacked = True)
plt.show()

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, \
        movies[movies.Genre == 'Adventure'].BudgetMillions, \
        movies[movies.Genre == 'Comedy'].BudgetMillions,  \
        movies[movies.Genre == 'Drama'].BudgetMillions,  \
        movies[movies.Genre == 'Horror'].BudgetMillions,  \
        movies[movies.Genre == 'Romance'].BudgetMillions, \
        movies[movies.Genre == 'Thriller'].BudgetMillions], 
        bins=15, stacked=True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
# Print unique values in the 'BudgetMillions' column
for value in sorted(movies['Genre'].unique()):
    print(value)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %% [markdown]
# # Countplot

# %%
c1 = sns.countplot(x='Genre', data=movies, hue='Genre')

# Add title and labels
plt.title('Genre Distribution', fontsize=16)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.show()

# %% [markdown]
# # KDE Plot  - - Visualizing KDE for Bivariate Data

# %%
k1 = sns.kdeplot(x=movies.CriticRating, y = movies.AudienceRating )

# %%
k2 = sns.kdeplot(x=movies.CriticRating, y = movies.AudienceRating, cmap = 'Blues', shade=True)

# Adding a title and showing the plot
plt.title('Audience V/s Critic Ratings', fontsize=15)
plt.show()

# %%
k3= sns.kdeplot(data = movies, x='CriticRating', y='AudienceRating', cmap= 'Reds')

# %%
k4= sns.kdeplot(data = movies, y='CriticRating', x='AudienceRating', cmap= 'Reds', shade=True)

#Title
plt.title('\nCritic V/S Audience Rating with Red Colour Map \n', fontsize=17)
plt.show()

# %%
k5= sns.kdeplot(data = movies, x='CriticRating', y='AudienceRating', cmap= 'Greens',shade_lowest=False, shade=True)

#Title
plt.title('\nCritic V/S Audience Rating with Red Colour Map \n', fontsize=17)
plt.show()

# %%
k6= sns.kdeplot(data = movies, x='CriticRating', y='AudienceRating', cmap= 'Greens_r',shade_lowest=False)

#Title
plt.title('\nCritic V/S Audience Rating with Red Colour Map \n', fontsize=17)
plt.show()

# %%
k7= sns.kdeplot(data = movies, x='BudgetMillions', y='AudienceRating', cmap= 'Greens_r')

#Adding Title
plt.title('\nCritic V/S Audience Rating with Red Colour Map \n', fontsize=17)
plt.show()

# %%
k8= sns.kdeplot(data = movies, x='BudgetMillions', y='AudienceRating', cmap= 'Reds', shade = True)

# %% [markdown]
# # Violin Plot

# %%
for i in movies.columns:
    print(i)
# Out:
# Film
# Genre
# CriticRating
# AudienceRating
# BudgetMillions
# Year

# %%
vio1= sns.violinplot(data=movies, x='Genre', y='BudgetMillions')

# %%
# Filter for Action movies only
action_movies = movies[movies['Genre'] == 'Action']

# Create the violin plot
vio2 = sns.violinplot(data=action_movies,y='BudgetMillions')

# Add a title
plt.title("Violin Plot: BudgetMillions for Action Movies")
plt.show()

# %%
movies_action = movies[movies['Genre']== 'Comedy']

voi3 = sns.violinplot(data = movies_action, x='Year',y='BudgetMillions')

#  Plot Title
plt.title('Violin Plot: BudgetMillions for Comedy Movies') 

# Axis Labeling
plt.xlabel('Year')
plt.ylabel('Budget in Millions Rupees')

plt.show()

# %%
for i in sorted(movies.columns):
    print(i)
# Out:
# AudienceRating
# BudgetMillions
# CriticRating
# Film
# Genre
# Year

# %%
# Re-Size the plot 
plt.figure(figsize=(15, 8)) 

# Filter for Comedy movies
comedy_movies = movies[movies['Genre'] == 'Action']

# Create the violin plot
voi4 = sns.violinplot(data=comedy_movies, x='Year', y='BudgetMillions')

# Plot Title and Labels
plt.title('Violin Plot: BudgetMillions for \nAction Movies by Year', fontsize=16, color='blue')
plt.xlabel('\nParticular Year of Released Movies')
plt.ylabel('Budget in Millions Rupees\n')


# Display the plot
plt.show()

# %%
sns.violinplot(data = movies, x='Genre', y= 'BudgetMillions', hue='Genre')

plt.title('Genre Movies of Budget in Millions\n')
plt.xlabel('Genre')
plt.ylabel('Budget in Millions')

plt.show()

# %% [markdown]
# # Scatter plot

# %%
for i in sorted(movies):
    print(i)
# Out:
# AudienceRating
# BudgetMillions
# CriticRating
# Film
# Genre
# Year

# %%
# Create a scatter plot
s1 = plt.scatter(data = movies,x='CriticRating', y='AudienceRating', color='blue', label='Data Points')

# Add labels, title, and legend
plt.xlabel('Critic Rating')
plt.ylabel('Audiences Rating')
plt.title('Scatter Plot Example')
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(data = movies, x='CriticRating', y ='AudienceRating', color= 'yellow', )

# %% [markdown]
# # Factet Grid

# %%
f1 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre',height=4, aspect=1.5)

# %%
f2 =sns.FacetGrid (data= movies, row = 'Genre', col = 'Year', hue = 'Genre')
sc1 = f2.map(plt.scatter, 'CriticRating', 'AudienceRating' ) #scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat. 
f3= sns.FacetGrid(movies, row='Genre', col='Year', hue= 'Genre')
sc2= f3.map(plt.hist, 'BudgetMillions')

# %%
f3 = sns.FacetGrid(movies, row='Genre', col='Year', hue= 'Genre')
s4= f3.map(sns.kdeplot, 'BudgetMillions')

# %% [markdown]
# # Subplot

# %%
# Subplot
fig, ax = plt.subplots(1,2, figsize=(8,6))

# %%
import matplotlib.pyplot as plt

# Create a 2x2 grid of subplots with specified figure size
fig, ax = plt.subplots(2, 2, figsize=(12, 6))

# Example plot in the bottom-right subplot (ax[1, 1])
ax[0, 0].plot([1, 2, 3], [4, 5, 6])
ax[0, 0].set_xlabel('Subplot X-axis')  # Set x-axis label for this subplot
ax[0, 0].set_ylabel('Subplot Y-axis')  # Set y-axis label for this subplot
ax[0, 0].set_title('Top-left Subplot')  # Optional: Title for this subplot

ax[0, 1].plot([1, 2, 3], [4, 5, 6])
ax[0, 1].set_xlabel('Subplot X-axis')  # Set x-axis label for this subplot
ax[0, 1].set_ylabel('Subplot Y-axis')  # Set y-axis label for this subplot
ax[0, 1].set_title('Top-Right Subplot')  # Optional: Title for this subplot

ax[1, 0].plot([1, 2, 3], [4, 5, 6])
ax[1, 0].set_xlabel('Subplot X-axis')  # Set x-axis label for this subplot
ax[1, 0].set_ylabel('Subplot Y-axis')  # Set y-axis label for this subplot
ax[1, 0].set_title('Bottom-Left Subplot')  # Optional: Title for this subplot

ax[1, 1].plot([1, 2, 3], [4, 5, 6])
ax[1, 1].set_xlabel('Subplot X-axis')  # Set x-axis label for this subplot
ax[1, 1].set_ylabel('Subplot Y-axis')  # Set y-axis label for this subplot
ax[1, 1].set_title('Bottom-Right Subplot')  # Optional: Title for this subplot


# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
for i in movies.columns:
    print(i)
# Out:
# Film
# Genre
# CriticRating
# AudienceRating
# BudgetMillions
# Year

# %%
fig1, sbp1 = plt.subplots(1,2, figsize=(8,4))
a1= sns.kdeplot(data=movies, x='CriticRating', y='BudgetMillions',  ax=sbp1[0])
a2= sns.scatterplot(data=movies, x='AudienceRating', y='BudgetMillions',ax=sbp1[1])

# %%
fig2, sbp2 = plt.subplots(1,2, figsize=(8,4))
a1= sns.kdeplot(data=movies, x='CriticRating', y='BudgetMillions', cmap= 'Reds', shade = True, ax=sbp2[0])
a2= sns.scatterplot(data=movies, x='AudienceRating', y='BudgetMillions',hue='Genre', ax=sbp2[1])

# Plot Title

# Labeling
sbp2[0].set_title('KDE Plot')
sbp2[0].set_xlabel('Critic Rating')
sbp2[0].set_ylabel('Budget in Millions')

sbp2[1].set_title('SCATTER Plot')
sbp2[1].set_xlabel('Audience Rating')
sbp2[1].set_ylabel('Budget in Millions')


# Adjust Label
plt.tight_layout()
plt.show()

# %%
# Subplot
fig3, sv = plt.subplots(5,3, figsize=(14,14))

# KDE Plot
b1 = sns.kdeplot(data=movies, x='BudgetMillions',y='CriticRating',cmap='Blues',ax=sv[0,0])
sv[0,0].set_title('KDE Plot - 01')
sv[0,0].set_xlabel('Budget in Millions')
sv[0,0].set_ylabel('Critic Rating')

b1 = sns.kdeplot(data=movies, x='BudgetMillions',y='CriticRating',cmap='Reds_r',ax=sv[0,1])
sv[0,1].set_title('KDE Plot - 02')
sv[0,1].set_xlabel('Budget in Millions')
sv[0,1].set_ylabel('Critic Rating')

b1 = sns.kdeplot(data=movies, x='BudgetMillions',y='CriticRating',cmap='Blues_r',shade= True, ax=sv[0,2])
sv[0,2].set_title('KDE Plot - 03')
sv[0,2].set_xlabel('Budget in Millions')
sv[0,2].set_ylabel('Critic Rating')

# SCATTER Plot
b2 = sns.scatterplot(data=movies, x='BudgetMillions',y='CriticRating',color = 'Yellow',ax=sv[1,0])
sv[1,0].set_title('SCATTER Plot - 01')
sv[1,0].set_xlabel('Budget in Millions')
sv[1,0].set_ylabel('Critic Rating')

b2 = sns.scatterplot(data=movies, x='BudgetMillions',y='CriticRating',color = 'Blue',ax=sv[1,1])
sv[1,1].set_title('SCATTER Plot - 02')
sv[1,1].set_xlabel('Budget in Millions')
sv[1,1].set_ylabel('Critic Rating')

b2 = sns.scatterplot(data=movies, x='BudgetMillions',y='CriticRating',color = 'Red',ax=sv[1,2])
sv[1,2].set_title('SCATTER Plot - 03')
sv[1,2].set_xlabel('Budget in Millions')
sv[1,2].set_ylabel('Critic Rating')

# HISTOGRAM
sv[2, 0].hist(movies['BudgetMillions'])
sv[2,0].set_title('HIST Plot - 01')
sv[2,0].set_xlabel('Budget in Millions')
sv[2,0].set_ylabel('Critic Rating')

sv[2, 1].hist(movies['CriticRating'])
sv[2,1].set_title('HIST Plot - 02')
sv[2,1].set_xlabel('Budget in Millions')
sv[2,1].set_ylabel('Critic Rating')

sv[2, 2].hist(movies['AudienceRating'])
sv[2,2].set_title('HIST Plot - 03')
sv[2,2].set_xlabel('Budget in Millions')
sv[2,2].set_ylabel('Critic Rating')

# VIOLIN Plot
b3 = sns.violinplot(data=movies, x='Genre', y='CriticRating', hue='Genre', ax=sv[3,0])
sv[3,0].set_title('VIOLIN Plot - 01')
sv[3,0].set_xlabel('Genre')
sv[3,0].set_ylabel('Critic Rating')

b3 = sns.violinplot(data=movies, x='Genre', y='AudienceRating', hue='Genre', ax=sv[3,1])
sv[3,1].set_title('VIOLIN Plot - 02')
sv[3,1].set_xlabel('Genre')
sv[3,1].set_ylabel('Audience Rating')

b3 = sns.violinplot(data=movies, x='Genre', y='BudgetMillions', hue='Genre', ax=sv[3,2])
sv[3,2].set_title('VIOLIN Plot - 03')
sv[3,2].set_xlabel('Genre')
sv[3,2].set_ylabel('Budget in Millions')


# BOX Plot
b4= sns.boxplot(data =movies[movies['Genre'] == 'Action'], x ='Year', y= 'BudgetMillions', color= 'red', ax=sv[4,0])
sv[4,0].set_title('Boxplot of Budget for Action Movies')
sv[4,0].set_xlabel('Year')
sv[4,0].set_ylabel('Budget in Millions')

b4= sns.boxplot(data =movies[movies['Genre'] == 'Adventure'], x ='Year', y= 'BudgetMillions', color= 'blue', ax=sv[4,1])
sv[4,1].set_title('Boxplot of Budget for Adventure Movies')
sv[4,1].set_xlabel('Year')
sv[4,1].set_ylabel('Budget in Millions')

b4= sns.boxplot(data =movies[movies['Genre'] == 'Drama'], x = 'Year', y= 'BudgetMillions', color= 'yellow', ax=sv[4,2])
sv[4,2].set_title('Boxplot of Budget for Drama Movies')
sv[4,2].set_xlabel('Year')
sv[4,2].set_ylabel('Budget in Millions')


# Map Layout Adjust
plt.tight_layout()

plt.show()
